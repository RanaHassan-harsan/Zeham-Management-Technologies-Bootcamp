# %% [markdown]
# <a href="https://colab.research.google.com/github/RanaHassan-harsan/Zeham-Management-Technologies-Bootcamp/blob/main/Week5/Day%205/Exponential_smoothing_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Exponential smoothing**

# %% [markdown]
# ##  install these libraries using pip:

# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/Trainees - المتدربين/Week 5/5- Introduction to Time Series Forecasting/5- Advanced topics in Time Series Forecasting/LAB/Datasets/traffic.csv')
df2 = data.copy('Vehicles')
print(df2)
# Out:
#                   DateTime  Junction  Vehicles           ID
# 0      2015-11-01 00:00:00         1        15  20151101001
# 1      2015-11-01 01:00:00         1        13  20151101011
# 2      2015-11-01 02:00:00         1        10  20151101021
# 3      2015-11-01 03:00:00         1         7  20151101031
# 4      2015-11-01 04:00:00         1         9  20151101041
# ...                    ...       ...       ...          ...
# 48115  2017-06-30 19:00:00         4        11  20170630194
# 48116  2017-06-30 20:00:00         4        30  20170630204
# 48117  2017-06-30 21:00:00         4        16  20170630214
# 48118  2017-06-30 22:00:00         4        22  20170630224
# 48119  2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %% [markdown]
# ## Visualizing the data

# %%
data=df2.iloc[:300]
plt.plot(data["Vehicles"])
plt.xlabel('DateTime')
plt.ylabel('Vehicles')
plt.show()

# %% [markdown]
# #**Single Exponential smoothing**

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
model = SimpleExpSmoothing(data['Vehicles'])
model_single_fit = model.fit()

# %% [markdown]
# ## Making predictions

# %%
forecast_single = model_single_fit.forecast(6)
print(forecast_single)
# Out:
# 300    40.440448
# 301    40.440448
# 302    40.440448
# 303    40.440448
# 304    40.440448
# 305    40.440448
# dtype: float64

# %% [markdown]
# ## Visualize Single Exponential Smoothing

# %%
forecast_single = model_single_fit.forecast(40)

# %%
plt.plot(data['Vehicles'], label='Vehicles')
plt.plot(model_single_fit.fittedvalues, label='Fitted Values')
plt.plot(forecast_single, label='Forecast')
plt.xlabel('DateTime')
plt.ylabel('Number of Vehicles')
plt.title('Single Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# #**Double Exponential Smoothing**

# %%
from statsmodels.tsa.api import Holt

model_double = Holt(data['Vehicles'])
model_double_fit = model_double.fit()

# %% [markdown]
# ## Making predictions

# %%
forecast_double = model_double_fit.forecast(6)
print(forecast_double)
# Out:
# 300    41.106996
# 301    41.518646
# 302    41.930296
# 303    42.341947
# 304    42.753597
# 305    43.165247
# dtype: float64

# %% [markdown]
# ## Visualize Double Exponential Smoothing

# %%
forecast_double = model_double_fit.forecast(40)

# %%
plt.plot(data['Vehicles'], label='Vehicles')
plt.plot(model_double_fit.fittedvalues, label='Fitted Values')
plt.plot(forecast_double, label='Forecast')
plt.xlabel('DateTime')
plt.ylabel('Number of Vehicles')
plt.title('Double Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# #**Holt-Winter’s Seasonal Smoothing**

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# Create an instance of ExponentialSmoothing class
model_triple = ExponentialSmoothing(
    data['Vehicles'], seasonal_periods=12, trend='add', seasonal='add')

# Fit the model to the data
model_triple_fit = model_triple.fit()

# %% [markdown]
# ## Making predictions

# %%
forecast_triple = model_triple_fit.forecast(6)
print(forecast_triple)
# Out:
# 300    37.214972
# 301    35.096800
# 302    34.939578
# 303    32.941540
# 304    31.940734
# 305    30.822108
# dtype: float64

# %% [markdown]
# ## Visualize Triple Exponential Smoothing

# %%
forecast_triple = model_triple_fit.forecast(40)

# %%
plt.plot(data['Vehicles'], label='Vehicles')
plt.plot(model_triple_fit.fittedvalues, label='Fitted Values')
plt.plot(forecast_triple, label='Forecast')
plt.xlabel('DateTime')
plt.ylabel('Number of Vehicles')
plt.title('Triple Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# ##**Well done :)**
